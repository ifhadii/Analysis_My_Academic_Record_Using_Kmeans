# %%
# installing required modules
# !pip install pandas
# !pip install numpy

# %%
# reading the csv file which hold our data
import pandas as pd
df = pd.read_csv('fahad_data.csv')
df.head(30)
# Out:
#                   Kingdom of Saudi Arabia                  Unnamed: 1  \
# 0                                     NaN                         NaN
# 1                        Jazan University                         NaN
# 2                                     NaN                         NaN
# 3   Deanship of Admissions & Registration                         NaN
# 4                                     NaN                         NaN
# 5                                     NaN                         NaN
# 6                                     NaN                         NaN
# 7               First Semester Year 20201                         NaN
# 8                             course code                         NaN
# 9                               100MATH-3                 Mathematics
# 10                               CSC101-3    Introduction to Computer
# 11                               SLM101-2           Islamic Culture I
# ...

# %%
# grade A+ list
a_p = []

# grade A list
a_ = []

# grade B+ list
b_p = []

# grade B list
b_ = []

# grade C+ list
c_p = []


# grade C list
c_ = []


# grade D+ list
d_p = []


# grade D list
d_ = []

# grade D list
f_ = []

# %%
for index, row in df.iterrows():  # Iterate over rows of the DataFrame
    for value in row:  # Iterate over values in the row
        if value == 'A+':  # Check if value is 'A+'
            a_p.append(value)  # If 'A+' is found, append it to a_p list

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ' '.join(a_p)
#       2 print(a_p)
#
# TypeError: sequence item 2: expected str instance, Series found
